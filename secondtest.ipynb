# %%
# Import all stuff we need
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.pylab as pylab

from brian import Network, Equations, NeuronGroup, Connection,\
    SpikeMonitor, raster_plot, StateMonitor, clear, reinit
from brian.stdunits import ms, mV, nS, pA, pF, Hz

# %matplotlib inline
pylab.rcParams['figure.figsize'] = 12, 8  # changes figure size (width, height) for larger images

clear(True, True) 
reinit()# To reinit brain clocks and remove all old brian objects from namespace,
# it's usually a good idea to put this at the beginning of a script



# The equations defining our neuron model

eqs_string = ''' dV/dt = (1.0/tau)*(myu-V) + Isyn : 1
             Isyn = 1/(tau2 - tau1) * IsynDerFac1 : hertz
             dIsynDerFac1/dt = 1*IsynDerFac2 : 1
             dIsynDerFac2/dt = (tau2+tau1)/(tau1*tau2)*IsynDerFac1/second + 1/(tau1*tau2)*IsynDerFac2*second : hertz
             myu : 1
             '''

eqs_string3 = ''' dV/dt = -1*hertz : 1 '''

eqs_string2 = '''
             dv/dt = (ge+gi-(v+49*mV))/(20*ms) : volt
             dge/dt = -ge/(5*ms) : volt
             dgi/dt = -gi/(10*ms) : volt
             '''

# Our model parameters
taue = 15*ms # time constant of membrane excitatory
taui = 10*ms # time constant of membrane inhibitory
tau1 = 1*ms
tau2e = 3*ms
tau2i = 2*ms
myueMax = 1.2
myueMin = 1.1
myuiMax = 1.05
myuiMin = 1.0
syn_delay = 5 # synaptic delay between two neurons
V_th = 1 # firing threshold
V_reset = 0 # reset potential
refr_period = 5*ms # absolute refractory period
bump = 1 #value to bump Isyn with on spike
jEE = 0.024
jEI = -0.045
jIE = 0.014
jII = -0.057
pEI = 0.5
pIE = pEI
pII = pEI
pEE = 0.2

# Number of neurons
N_e = 4000 # number of exc neurons
N_i = 1000 # number of inh neurons

# Connection probability
conn_prob = 0.05

# Duration of our simulation
duration = 2500*ms

# Let's create an equation object from our string and parameters
model_eqs_e = Equations(eqs_string,
                      tau=taue,
                      tau1=tau1,
                      tau2=tau2e,
                      )

model_eqs_i = Equations(eqs_string,
                      tau=taui,
                      tau1=tau1,
                      tau2=tau2i,
                      )


# Divide the neurons into excitatory and inhibitory ones
neurons_e = NeuronGroup(N=N_e,
                          model=model_eqs_e,
                          threshold=V_th,
                          reset=V_reset,
                          refractory=refr_period,
                          freeze = True,
                          method='Euler',
                          compile=True)

neurons_i = NeuronGroup(N=N_i,
                          model=model_eqs_i,
                          threshold=V_th,
                          reset=V_reset,
                          refractory=refr_period,
                          freeze = True,
                          method='Euler',
                          compile=True)


neurons_e.myu = np.random.uniform(myueMin, myueMax, N_e)
neurons_i.myu = np.random.uniform(myuiMin, myuiMax, N_i)





# Set the connections
conn_ee = Connection(neurons_e,
                    neurons_e,
                    'IsynDerFac1',
                    delay=syn_delay,
                    weight = jEE*bump,
                    sparseness=pEE)

conn_ei = Connection(neurons_e,
                    neurons_i,
                    'IsynDerFac1',
                    delay=syn_delay,
                    weight = jEI*bump,
                    sparseness=pEI)

conn_ie = Connection(neurons_i,
                    neurons_e,
                    'IsynDerFac1',
                    delay=syn_delay,
                    weight = jIE*bump,
                    sparseness=pIE)

conn_ii = Connection(neurons_i,
                    neurons_i,
                    'IsynDerFac1',
                    delay=syn_delay,
                    weight = jII*bump,
                    sparseness=pII)



# Set the initial membrane potential somewhere between the reversal potential and slightly
# above the firing threshold. This will make some cells fire at t=0.
neurons_e.V = V_reset
neurons_i.V = V_reset




# Make some monitors to record spikes of all neurons and the membrane potential of a few
spike_mon_e = SpikeMonitor(neurons_e)
spike_mon_i = SpikeMonitor(neurons_i)
state_mon_v_e = StateMonitor(neurons_e, 'V', record=[0,1,2])
state_mon_v_i = StateMonitor(neurons_i, 'V', record=[0,1])




# Put everything into the network
network = Network(neurons_e, neurons_i, conn_ee, conn_ei, conn_ie, conn_ii, spike_mon_e, state_mon_v_e)
# Alternatively use `add`
network.add(spike_mon_i, state_mon_v_i)




# Let's run our simulation
network.run(duration, report='text')




# Plot spike raster plots, blue exc neurons, red inh neurons
plt.figure()
gs = gridspec.GridSpec(2, 1, height_ratios=[1, 3])
plt.subplot(gs[0])
raster_plot(spike_mon_i, color='r')
plt.title('Inhibitory neurons')
plt.subplot(gs[1])
raster_plot(spike_mon_e)
plt.title('Excitatory neurons')

# Plot the evolution of the membrane potentials
plt.figure()
for irun in range(1,6):
    plt.subplot(6,1,irun)
    if irun < 3:
        mon = state_mon_v_i
        idx = irun-1
        color='r'
    else:
        mon = state_mon_v_e
        idx = irun-3
        color='b'

    y =  mon.values[idx,:]
    x = mon.times
    plt.plot(x, y, color)
    plt.yticks([min(y), (max(y)-min(y))/2.0+min(y)])

    if irun == 5:
        plt.xlabel('t in ms')
        plt.ylabel('V in volt')

# Show the plots
plt.show()
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-66e16503f2e9> in <module>()
#     160
#     161 # Put everything into the network
# --> 162 network = Network(all_neurons, conn_ee, conn_ei, conn_ie, conn_ii, spike_mon_e, state_mon_v_e)
#     163 # Alternatively use `add`
#     164 network.add(spike_mon_i, state_mon_v_i)
#
# /usr/lib/pymodules/python2.7/brian/network.pyc in __init__(self, *args, **kwds)
#     203         self.prepared = False
#     204         for o in chain(args, kwds.itervalues()):
# --> 205             self.add(o)
#     206
#     207     def add(self, *objs):
#
# /usr/lib/pymodules/python2.7/brian/network.pyc in add(self, *objs)
#     222             elif isSequenceType(obj):
#     223                 for o in obj:
# --> 224                     self.add(o)
#     225             else:
#     226                 raise TypeError('Only the following types of objects can be added to a network: NeuronGroup, Connection or NetworkOperation')
#
# /usr/lib/pymodules/python2.7/brian/network.pyc in add(self, *objs)
#     227
#     228             try:
# --> 229                 gco = obj.contained_objects
#     230                 if gco is not None:
#     231                     self.add(gco)
#
# /usr/lib/pymodules/python2.7/brian/base.pyc in get_contained_objects(self)
#      25         if hasattr(self, '_contained_objects'):
#      26             return self._contained_objects
# ---> 27         self._contained_objects = []
#      28         return self._contained_objects
#      29
#
# /usr/lib/pymodules/python2.7/brian/neurongroup.pyc in __setattr__(self, name, val)
#     612             self.link_var(name, val.source, val.var, val.func, val.when, val.clock)
#     613         else:
# --> 614             Group.__setattr__(self, name, val)
#     615
#     616     def link_var(self, var, source, sourcevar, func=None, when='start', clock=None):
#
# /usr/lib/pymodules/python2.7/brian/group.pyc in __setattr__(self, name, val)
#      84         if len(name) and name[-1] == '_':
#      85             origname = name[:-1]
# ---> 86         if not hasattr(self, 'var_index') or (name not in self.var_index and origname not in self.var_index):
#      87             object.__setattr__(self, name, val)
#      88         else:
#
# TypeError: argument of type 'NoneType' is not iterable
# ERROR: Line magic function `%matplotlib` not found.
